# %%
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import Request,urlopen

# %%
req=Request('https://www.passportindex.org/byRank.php',headers={'User-Agent':'Mozilla/5.0'})
webpage=urlopen(req).read()

# %%
print(webpage)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n<script type="0f6df59e554dcf8c447f47dc-text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-W7492WC\');</script>\n\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no">\n<meta name="p:domain_verify" content="8a9838738f3dcceaf0675fe08db42b50" />\n<meta name="apple-itunes-app" content="app-id=1488786142" />\n<title>Global Passport Power Rank 2021 | Passport Index 2021</title>\n<meta name="description" content="Explore the interactive global ranking of the world\'s passports in real-time. Which passport is ranked 1st? Which is last? Find out on Passport Index!">\n<link href="https://www.passportindex.org/css/bootstrap.min.css?ver=2.28" rel="stylesheet">\n<link href="https://www.passportindex.org/css/pistyle.css?ver=2.28" rel="stylesheet">\n\n<!--[if lt IE 9]>\n      <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\n      <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\n    <!--[endif]-->\n<link rel="canonical" href="https://www.passportindex.org/byRank.php" />\n<link rel="alternate" hreflang="en" href="https://www.passportindex.org/byRank.php" />\n<link rel="alternate" hreflang="de" href="https://www.passportindex.org/de/byRank.php" />\n<link rel="alternate" hreflang="es" href="https://www.passportindex.org/es/byRank.php" />\n<link rel="alternate" hreflang="pt" href="https://www.passportindex.org/pt/byRank.php" />\n<link rel="alternate" hreflang="ru" href="https://www.passportindex.org/ru/byRank.php" />\n<link rel="alternate" hreflang="fr" href="https://www.passportindex.org/fr/byRank.php" />\n<link rel="publisher" href="103179848885863235032" />\n<meta property=\'og:type\' content=\'article\' />\n<meta property=\'og:title\' content="Global Passport Power Rank 2021 | Passport Index 2021" />\n<meta property=\'og:description\' content="Explore the interactive global ranking of the world\'s passports in real-time. Which passport is ranked 1st? Which is last? Find out on Passport Index!" />\n<meta property=\'og:url\' content=\'https://www.passportindex.org/byRank.php\' />\n<meta property="og:image" content="https://www.passportindex.org/images/social/Passport-Index-Rank-Global.jpg" />\n<meta property=\'og:site_name\' content="Passport Index - Global Mobility Intelligence" />\n<meta property=\'og:locale\' content=\'en_US\' />\n<meta property=\'article:publisher\' content=\'https://www.facebook.com/passportindex\' />\n<meta property=\'fb:app_id\' content=\'861964690537314\' />\n\n<meta name="theme-color" content="#000">\n\n<meta name="msapplication-navbutton-color" content="#000">\n\n<meta name="apple-mobile-web-app-capable" content="yes">\n<meta name="apple-mobile-web-app-status-bar-style" content="black-translucent">\n<link rel="icon" href="https://www.passportindex.org/favicon.ico">\n<link rel="shortcut icon" href="https://www.passportindex.org/images/fav/favicon-16.png" type="image/png" />\n<link rel="icon" sizes="16x16" href="https://www.passportindex.org/images/fav/favicon-16.png" type="image/png">\n<link rel="icon" sizes="32x32" href="https://www.passportindex.org/images/fav/favicon-32.png" type="image/png">\n<link rel="apple-touch-icon" sizes="60x60" href="https://www.passportindex.org/images/fav/favicon-60.png" type="image/png">\n<link rel="apple-touch-icon" sizes="76x76" href="https://www.passportindex.org/images/fav/favicon-76.png" type="image/png">\n<link rel="apple-touch-icon" sizes="114x114" href="https://www.passportindex.org/images/fav/favicon-114.png" type="image/png">\n<link re ...

# %%
soup=BeautifulSoup(webpage,'html')

# %%
country_name_html=[i for i in soup.find_all(class_='name_country')]

# %%
country_name=list()

# %%
for i in range(len(country_name_html)):
  country_name.append(country_name_html[i].text)

print(country_name)
# Out:
# ['Germany', 'Finland', 'Spain', 'Switzerland', 'Austria', 'Italy', 'Ireland', 'Sweden', 'Netherlands', 'Denmark', 'Belgium', 'France', 'Portugal', 'Czech Republic', 'Greece', 'Hungary', 'New Zealand', 'Malta', 'Slovenia', 'Luxembourg', 'Norway', 'Poland', 'Slovakia', 'South Korea', 'Lithuania', 'Estonia', 'Latvia', 'United Kingdom', 'Australia', 'Iceland', 'Japan', 'Cyprus', 'Croatia', 'Liechtenstein', 'Romania', 'Bulgaria', 'Singapore', 'Monaco', 'San Marino', 'United Arab Emirates', 'Andorra', 'Canada', 'Vatican City', 'United States of America', 'Uruguay', 'Malaysia', 'Brazil', 'Chile', 'Argentina', 'Russian Federation', 'Israel', 'Turkey', 'Hong Kong', 'Barbados', 'Brunei', 'Mexico', 'Bahamas', 'Ukraine', 'Seychelles', 'Saint Kitts and Nevis', 'Antigua and Barbuda', 'St. Vincent and the Grenadines', 'Costa Rica', 'Trinidad and Tobago', 'Mauritius', 'Macao', 'Serbia', 'Georgia', 'Qatar', 'Peru', 'Saint Lucia', 'Panama', 'Paraguay', 'Kuwait', 'Grenada', 'Dominica', 'South Africa', 'Solomon Islands', 'Venezuela', 'Vanuatu', 'Taiwan', 'North Macedonia', 'Colombia', 'Belize', 'Tuvalu', 'Tonga', 'Samoa', 'Bosnia and Herzegovina', 'El Salvador', 'Montenegro', 'Honduras', 'Jamaica', 'Kiribati', 'Guatemala', 'Bahrain', 'Ecuador', 'Fiji', 'Maldives', 'Albania', 'Moldova', 'Marshall Islands', 'Nicaragua', 'Guyana', 'Belarus', 'Oman', 'Saudi Arabia', 'Kazakhstan', 'Botswana', 'Nauru', 'Micronesia', 'Palau', 'Bolivia', 'Lesotho', 'Azerbaijan', 'Suriname', 'Namibia', 'Tunisia', 'Papua New Guinea', 'Thailand', 'Malawi', 'Zambia', 'China', 'Indonesia', 'Eswatini', 'Tanzania', 'Kenya', 'Cuba', 'Kyrgyzstan', 'Ghana', 'Armenia', 'Gambia', 'Cape Verde', 'Rwanda', 'Uzbekistan', 'Zimbabwe', 'Uganda', 'Morocco', 'Timor-Leste', 'Sao Tome and Principe', 'Dominican Republic', 'Tajikistan', 'Sierra Leone', 'Mozambique', 'India', 'Senegal', 'Burkina Faso', "Cote d'Ivoire (Ivory Coast)", 'Benin', 'Philippines', 'Mongolia', 'Jordan', 'Algeria', 'Bhutan', 'Madagascar', 'Gabon', 'Turkmenistan', 'Guinea-Bissau', 'Mauritania', 'Angola', 'Cambodia', 'Niger', 'Togo', 'Equatorial Guinea', 'Egypt', 'Guinea', 'Cameroon', 'Burundi', 'Comoros', 'Viet Nam', 'Mali', 'Liberia', 'Chad', 'Central African Republic', 'Laos', 'Kosovo', 'Djibouti', 'Haiti', 'Nigeria', 'South Sudan', 'Congo (Dem. Rep.)', 'Lebanon', 'Bangladesh', 'Sri Lanka', 'Libya', 'Congo', 'Sudan', 'North Korea', 'Ethiopia', 'Nepal', 'Eritrea', 'Myanmar [Burma]', 'Palestinian Territories', 'Iran', 'Yemen', 'Pakistan', 'Somalia', 'Syria', 'Iraq', 'Afghanistan']

# %%
VFS_html=[i for i in soup.find_all(class_='name_rank')]

# %%
VFS=list()
FS=list()

for i in range(len(VFS_html)):
  VFS.append(VFS_html[i].text)

# %%
print(VFS)
# Out:
# ['137', '136', '136', '136', '135', '135', '135', '134', '134', '134', '134', '134', '134', '134', '134', '134', '134', '133', '133', '133', '133', '133', '133', '133', '132', '131', '131', '131', '131', '130', '130', '129', '129', '129', '129', '128', '123', '123', '120', '120', '115', '115', '113', '112', '109', '104', '103', '102', '100', '99', '99', '99', '97', '97', '94', '94', '93', '92', '91', '90', '90', '88', '88', '87', '86', '86', '86', '86', '85', '85', '84', '84', '84', '83', '82', '82', '82', '81', '81', '79', '79', '79', '78', '77', '77', '77', '77', '77', '77', '76', '76', '75', '75', '75', '75', '75', '74', '74', '74', '73', '73', '73', '72', '72', '71', '70', '70', '68', '68', '68', '67', '67', '65', '65', '65', '64', '64', '64', '64', '63', '63', '63', '63', '62', '61', '61', '61', '61', '60', '60', '59', '59', '59', '59', '58', '58', '58', '58', '58', '58', '57', '56', '55', '55', '54', '54', '54', '53', '53', '53', '53', '53', '53', '52', '52', '52', '51', '51', '51', '51', '50', '50', '50', '50', '49', '49', '49', '48', '48', '47', '47', '47', '47', '47', '45', '45', '45', '44', '44', '44', '44', '43', '43', '43', '43', '43', '43', '42', '42', '41', '40', '38', '37', '36', '36', '34', '32', '31', '30']

# %%
rank_vf_html=[i for i in soup.find_all(class_='rank vf')]
rank_vf=list()
for i in range(len(rank_vf_html)):
  rank_vf.append(rank_vf_html[i].text)

# %%
rank_voa_html=[i for i in soup.find_all(class_='rank voa')]
rank_voa=list()
for i in range(len(rank_voa_html)):
  rank_voa.append(rank_voa_html[i].text)

# %%
rank_vr_html=[i for i in soup.find_all(class_='rank vr')]
rank_vr=list()
for i in range(len(rank_vr_html)):
  rank_vr.append(rank_vr_html[i].text)

# %%
dict1={'country':country_name,'VFS':VFS,'rank_vf':rank_vf,'rank_voa':rank_voa,'rank_vr':rank_vr}

# %%
print(dict1)
# Out:
# {'country': ['Germany', 'Finland', 'Spain', 'Switzerland', 'Austria', 'Italy', 'Ireland', 'Sweden', 'Netherlands', 'Denmark', 'Belgium', 'France', 'Portugal', 'Czech Republic', 'Greece', 'Hungary', 'New Zealand', 'Malta', 'Slovenia', 'Luxembourg', 'Norway', 'Poland', 'Slovakia', 'South Korea', 'Lithuania', 'Estonia', 'Latvia', 'United Kingdom', 'Australia', 'Iceland', 'Japan', 'Cyprus', 'Croatia', 'Liechtenstein', 'Romania', 'Bulgaria', 'Singapore', 'Monaco', 'San Marino', 'United Arab Emirates', 'Andorra', 'Canada', 'Vatican City', 'United States of America', 'Uruguay', 'Malaysia', 'Brazil', 'Chile', 'Argentina', 'Russian Federation', 'Israel', 'Turkey', 'Hong Kong', 'Barbados', 'Brunei', 'Mexico', 'Bahamas', 'Ukraine', 'Seychelles', 'Saint Kitts and Nevis', 'Antigua and Barbuda', 'St. Vincent and the Grenadines', 'Costa Rica', 'Trinidad and Tobago', 'Mauritius', 'Macao', 'Serbia', 'Georgia', 'Qatar', 'Peru', 'Saint Lucia', 'Panama', 'Paraguay', 'Kuwait', 'Grenada', 'Dominica', 'South Africa', 'Solomon Islands', 'Venezuela', 'Vanuatu', 'Taiwan', 'North Macedonia', 'Colombia', 'Belize', 'Tuvalu', 'Tonga', 'Samoa', 'Bosnia and Herzegovina', 'El Salvador', 'Montenegro', 'Honduras', 'Jamaica', 'Kiribati', 'Guatemala', 'Bahrain', 'Ecuador', 'Fiji', 'Maldives', 'Albania', 'Moldova', 'Marshall Islands', 'Nicaragua', 'Guyana', 'Belarus', 'Oman', 'Saudi Arabia', 'Kazakhstan', 'Botswana', 'Nauru', 'Micronesia', 'Palau', 'Bolivia', 'Lesotho', 'Azerbaijan', 'Suriname', 'Namibia', 'Tunisia', 'Papua New Guinea', 'Thailand', 'Malawi', 'Zambia', 'China', 'Indonesia', 'Eswatini', 'Tanzania', 'Kenya', 'Cuba', 'Kyrgyzstan', 'Ghana', 'Armenia', 'Gambia', 'Cape Verde', 'Rwanda', 'Uzbekistan', 'Zimbabwe', 'Uganda', 'Morocco', 'Timor-Leste', 'Sao Tome and Principe', 'Dominican Republic', 'Tajikistan', 'Sierra Leone', 'Mozambique', 'India', 'Senegal', 'Burkina Faso', "Cote d'Ivoire (Ivory Coast)", 'Benin', 'Philippines', 'Mongolia', 'Jordan', 'Algeria', 'Bhutan', 'Madagascar', 'Gabon', 'Turkmenistan', 'Guinea-Bissau', 'Mauritania', 'Angola', 'Cambodia', 'Niger', 'Togo', 'Equatorial Guinea', 'Egypt', 'Guinea', 'Cameroon', 'Burundi', 'Comoros', 'Viet Nam', 'Mali', 'Liberia', 'Chad', 'Central African Republic', 'Laos', 'Kosovo', 'Djibouti', 'Haiti', 'Nigeria', 'South Sudan', 'Congo (Dem. Rep.)', 'Lebanon', 'Bangladesh', 'Sri Lanka', 'Libya', 'Congo', 'Sudan', 'North Korea', 'Ethiopia', 'Nepal', 'Eritrea', 'Myanmar [Burma]', 'Palestinian Territories', 'Iran', 'Yemen', 'Pakistan', 'Somalia', 'Syria', 'Iraq', 'Afghanistan'], 'VFS': ['137', '136', '136', '136', '135', '135', '135', '134', '134', '134', '134', '134', '134', '134', '134', '134', '134', '133', '133', '133', '133', '133', '133', '133', '132', '131', '131', '131', '131', '130', '130', '129', '129', '129', '129', '128', '123', '123', '120', '120', '115', '115', '113', '112', '109', '104', '103', '102', '100', '99', '99', '99', '97', '97', '94', '94', '93', '92', '91', '90', '90', '88', '88', '87', '86', '86', '86', '86', '85', '85', '84', '84', '84', '83', '82', '82', '82', '81', '81', '79', '79', '79', '78', '77', '77', '77', '77', '77', '77', '76', '76', '75', '75', '75', '75', '75', '74', '74', '74', '73', '73', '73', '72', '72', '71', '70', '70', '68', '68', '68', '67', '67', '65', '65', '65', '64', '64', '64', '64', '63', '63', '63', '63', '62', '61', '61', '61', '61', '60', '60', '59', '59', '59', '59', '58', '58', '58', '58', '58', '58', '57', '56', '55', '55', '54', '54', '54', '53', '53', '53', '53', '53', '53', '52', '52', '52', '51', '51', '51', '51', '50', '50', '50', '50', '49', '49', '49', '48', '48', '47', '47', '47', '47', '47', '45', '45', '45', '44', '44', '44', '44', '43', '43', '43', '43', '43', '43', '42', '42', '41', '40', '38', '37', '36', '36', '34', '32', '31', '30'], 'rank_vf': ['100', '99', '99', '96', '99', '99', '96', '99', '99', '99', '99', '99', '99', '98', '97', '97', '89', '99', '97', '97', '96', '96', '96', '93', '95', '95', '95', '92', '86', '93', '90', '96', ' ...

# %%
df=pd.DataFrame.from_dict(dict1)

# %%
df
# Out:
#          country  VFS rank_vf rank_voa rank_vr
# 0        Germany  137     100       37      61
# 1        Finland  136      99       37      62
# 2          Spain  136      99       37      62
# 3    Switzerland  136      96       40      62
# 4        Austria  135      99       36      63
# ..           ...  ...     ...      ...     ...
# 194     Pakistan   36       7       29     162
# 195      Somalia   34       8       26     164
# 196        Syria   32       5       27     166
# 197         Iraq   31       4       27     167
# 198  Afghanistan   30       4       26     168
#
# [199 rows x 5 columns]

# %%
df.head()
# Out:
#        country  VFS rank_vf rank_voa rank_vr
# 0      Germany  137     100       37      61
# 1      Finland  136      99       37      62
# 2        Spain  136      99       37      62
# 3  Switzerland  136      96       40      62
# 4      Austria  135      99       36      63

# %%
df.tail()
# Out:
#          country VFS rank_vf rank_voa rank_vr
# 194     Pakistan  36       7       29     162
# 195      Somalia  34       8       26     164
# 196        Syria  32       5       27     166
# 197         Iraq  31       4       27     167
# 198  Afghanistan  30       4       26     168
